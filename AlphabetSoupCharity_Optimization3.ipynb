# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
app_df_dropped = application_df.drop(columns = ["EIN", "NAME", "USE_CASE"])
app_df_dropped.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION  ORGANIZATION  STATUS  \
# 0              T10       Independent          C1000   Association       1
# 1               T3       Independent          C2000  Co-operative       1
# 2               T5  CompanySponsored          C3000   Association       1
# 3               T3  CompanySponsored          C2000         Trust       1
# 4               T3       Independent          C1000         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_counts = app_df_dropped["APPLICATION_TYPE"].value_counts()

# %%
# Choose a cutoff value (count < 100) and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# Saving the top 9 index values
application_types_to_replace = app_type_counts.index[9:].tolist()

# %%
# Replace in dataframe
for app in application_types_to_replace:
    app_df_dropped['APPLICATION_TYPE'] = app_df_dropped['APPLICATION_TYPE'].replace(app,"Other")

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = app_df_dropped["CLASSIFICATION"].value_counts()

# %%
# Choose a cutoff value (count < 500) and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# Saving the top 6 values in this case
classifications_to_replace = class_counts.index[6:].tolist()

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    app_df_dropped['CLASSIFICATION'] = app_df_dropped['CLASSIFICATION'].replace(cls,"Other")

# %%
# Convert categorical data to numeric with `pd.get_dummies`
encoded_df = pd.get_dummies(app_df_dropped, columns = ["APPLICATION_TYPE", "AFFILIATION", "CLASSIFICATION",\
                                                                    "ORGANIZATION", "INCOME_AMT",\
                                                                     "SPECIAL_CONSIDERATIONS"])

# %%
# Split our preprocessed data into our features and target arrays
X = encoded_df.drop(columns = "IS_SUCCESSFUL").values
y = encoded_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
hl1_units = 16
hl2_units = 16
hl3_units = 16

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hl1_units, activation = "relu", input_dim = 40))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = hl2_units, activation = "relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units = hl3_units, activation = "relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                656
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 16)                272
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,217
# Trainable params: 1,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
fit_model = nn.fit(X_train_scaled, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 988us/step - loss: 0.5841 - accuracy: 0.7091
# Epoch 2/50
# 804/804 [==============================] - 1s 974us/step - loss: 0.5592 - accuracy: 0.7253
# Epoch 3/50
# 804/804 [==============================] - 1s 972us/step - loss: 0.5555 - accuracy: 0.7269
# Epoch 4/50
# 804/804 [==============================] - 1s 966us/step - loss: 0.5534 - accuracy: 0.7294
# Epoch 5/50
# 804/804 [==============================] - 1s 971us/step - loss: 0.5518 - accuracy: 0.7291
# Epoch 6/50
# 804/804 [==============================] - 1s 978us/step - loss: 0.5513 - accuracy: 0.7302
# Epoch 7/50
# 804/804 [==============================] - 1s 967us/step - loss: 0.5503 - accuracy: 0.7294
# Epoch 8/50
# 804/804 [==============================] - 1s 969us/step - loss: 0.5498 - accuracy: 0.7306
# Epoch 9/50
# 804/804 [==============================] - 1s 967us/step - loss: 0.5491 - accuracy: 0.7308
# Epoch 10/50
# 804/804 [==============================] - 1s 967us/step - loss: 0.5487 - accuracy: 0.7318
# Epoch 11/50
# 804/804 [==============================] - 1s 969us/step - loss: 0.5487 - accuracy: 0.7320
# Epoch 12/50
# 804/804 [==============================] - 1s 967us/step - loss: 0.5483 - accuracy: 0.7321
# Epoch 13/50
# 804/804 [==============================] - 1s 962us/step - loss: 0.5480 - accuracy: 0.7323
# Epoch 14/50
# 804/804 [==============================] - 1s 971us/step - loss: 0.5479 - accuracy: 0.7318
# Epoch 15/50
# 804/804 [==============================] - 1s 974us/step - loss: 0.5474 - accuracy: 0.7324
# Epoch 16/50
# 804/804 [==============================] - 1s 995us/step - loss: 0.5472 - accuracy: 0.7324
# Epoch 17/50
# 804/804 [==============================] - 1s 988us/step - loss: 0.5472 - accuracy: 0.7334
# Epoch 18/50
# 804/804 [==============================] - 1s 986us/step - loss: 0.5475 - accuracy: 0.7317
# Epoch 19/50
# 804/804 [==============================] - 1s 977us/step - loss: 0.5468 - accuracy: 0.7331
# Epoch 20/50
# 804/804 [==============================] - 1s 970us/step - loss: 0.5469 - accuracy: 0.7332
# Epoch 21/50
# 804/804 [==============================] - 1s 966us/step - loss: 0.5466 - accuracy: 0.7329
# Epoch 22/50
# 804/804 [==============================] - 1s 972us/step - loss: 0.5470 - accuracy: 0.7331
# Epoch 23/50
# 804/804 [==============================] - 1s 969us/step - loss: 0.5468 - accuracy: 0.7333
# Epoch 24/50
# 804/804 [==============================] - 1s 965us/step - loss: 0.5464 - accuracy: 0.7331
# Epoch 25/50
# 804/804 [==============================] - 1s 965us/step - loss: 0.5467 - accuracy: 0.7331
# Epoch 26/50
# 804/804 [==============================] - 1s 967us/step - loss: 0.5461 - accuracy: 0.7331
# Epoch 27/50
# 804/804 [==============================] - 1s 963us/step - loss: 0.5462 - accuracy: 0.7334
# Epoch 28/50
# 804/804 [==============================] - 1s 958us/step - loss: 0.5462 - accuracy: 0.7325
# Epoch 29/50
# 804/804 [==============================] - 1s 964us/step - loss: 0.5456 - accuracy: 0.7345
# Epoch 30/50
# 804/804 [==============================] - 1s 961us/step - loss: 0.5459 - accuracy: 0.7337
# Epoch 31/50
# 804/804 [==============================] - 1s 976us/step - loss: 0.5461 - accuracy: 0.7331
# Epoch 32/50
# 804/804 [==============================] - 1s 991us/step - loss: 0.5459 - accuracy: 0.7336
# Epoch 33/50
# 804/804 [==============================] - 1s 971us/step - loss: 0.5459 - accuracy: 0.7336
# Epoch 34/50
# 804/804 [==============================] - 1s 940us/step - loss: 0.5452 - accuracy: 0.7328
# Epoch 35/50
# 804/804 [==============================] - 1s 945us/step - loss: 0.5456 - accuracy: 0.7340
# Epoch 36/50
# 804/804 [==============================] - 1s 959us/step - loss: 0.5454 - accuracy: 0.7340
# Epoch 37/50
# 804/804 [==============================] - 1s 981us/step - loss: 0.5455 - accuracy: 0.7334
# Epoch 38/50
# 804/804 [==============================] - 1s 965us/step - loss: 0.5452 - accuracy: 0.7330
# Epoch 39/50
# 804/804 [==============================] - 1s 964us/step - loss: 0.5453 - accuracy: 0.7336
# Epoch 40/50
# 804/804 [==============================] - 1s 974us/step - loss: 0.5448 - accuracy: 0.7336
# Epoch 41/50
# 804/804 [==============================] - 1s 972us/step - loss: 0.5451 - accuracy: 0.7352
# Epoch 42/50
# 804/804 [==============================] - 1s 967us/step - loss: 0.5450 - accuracy: 0.7336
# Epoch 43/50
# 804/804 [==============================] - 1s 973us/step - loss: 0.5446 - accuracy: 0.7348
# Epoch 44/50
# 804/804 [==============================] - 1s 975us/step - loss: 0.5450 - accuracy: 0.7345
# Epoch 45/50
# 804/804 [==============================] - 1s 962us/step - loss: 0.5446 - accuracy: 0.7340
# Epoch 46/50
# 804/804 [==============================] - 1s 973us/step - loss: 0.5446 - accuracy: 0.7352
# Epoch 47/50
# 804/804 [==============================] - 1s 999us/step - loss: 0.5441 - accuracy: 0.7344
# Epoch 48/50
# 804/804 [==============================] - 1s 977us/step - loss: 0.5443 - accuracy: 0.7350
# Epoch 49/50
# 804/804 [==============================] - 1s 974us/step - loss: 0.5445 - accuracy: 0.7338
# Epoch 50/50
# 804/804 [==============================] - 1s 949us/step - loss: 0.5442 - accuracy: 0.7338

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5545 - accuracy: 0.7298 - 291ms/epoch - 1ms/step
# Loss: 0.554469108581543, Accuracy: 0.7297959327697754

# %%
nn.save("AlphabetSoupCharityOpt3.h5")
